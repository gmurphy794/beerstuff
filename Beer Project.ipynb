# %%
# Setting Up Dependencies
import requests
import pandas as pd
import matplotlib.pyplot as plt
import time
import gmaps
from config import api_key
from config import w_key
import numpy as np

gkey = api_key
gmaps.configure(api_key=gkey)

# %%
brewery_id = []

for x in range(100):
    brewery_id.append(np.random.randint(0, 6000))

    brewery_id

unique_brewery = pd.DataFrame({"ID" : brewery_id})

unique_id = list(unique_brewery["ID"].unique())

print(f"Gathered {len(unique_id)} unique Brewery IDs.")
# Out:
# Gathered 100 unique Brewery IDs.

# %%
# Retrieving Raw Brewery Data
raw_brewery_data = []
start = time.time()
for x in range(len(unique_id)):
    try:
        url = "https://api.openbrewerydb.org/breweries/" + str(unique_id[x])
        response = requests.get(url).json()
        raw_brewery_data.append(response)
        print(f"({x+1}/{len(unique_id)}) Retrieved Brewery ID {unique_id[x]}...")

    except:
        print(f"({x+1}/{len(unique_id)}) Timeout for Brewery ID {unique_id[x]}... skipping")
        
stop = time.time()
time_elapsed = round((stop - start)/60,2)
print(f"\nRetrieved {len(unique_id)} breweries... Time elapsed: {time_elapsed} minutes.")
# Out:
# (1/100) Retrieved Brewery ID 1613...
# (2/100) Retrieved Brewery ID 4003...
# (3/100) Retrieved Brewery ID 751...
# (4/100) Retrieved Brewery ID 1707...
# (5/100) Retrieved Brewery ID 342...
# (6/100) Retrieved Brewery ID 86...
# (7/100) Retrieved Brewery ID 5499...
# (8/100) Retrieved Brewery ID 3874...
# (9/100) Retrieved Brewery ID 3362...
# (10/100) Retrieved Brewery ID 4698...
# (11/100) Retrieved Brewery ID 5286...
# (12/100) Retrieved Brewery ID 3652...
# (13/100) Retrieved Brewery ID 694...
# (14/100) Retrieved Brewery ID 2934...
# (15/100) Retrieved Brewery ID 3558...
# (16/100) Retrieved Brewery ID 1757...
# (17/100) Retrieved Brewery ID 487...
# (18/100) Retrieved Brewery ID 5506...
# (19/100) Retrieved Brewery ID 3239...
# (20/100) Retrieved Brewery ID 837...
# (21/100) Retrieved Brewery ID 2390...
# (22/100) Retrieved Brewery ID 891...
# (23/100) Retrieved Brewery ID 5919...
# (24/100) Retrieved Brewery ID 4293...
# (25/100) Retrieved Brewery ID 244...
# (26/100) Retrieved Brewery ID 3872...
# (27/100) Retrieved Brewery ID 2458...
# (28/100) Retrieved Brewery ID 4056...
# (29/100) Retrieved Brewery ID 521...
# (30/100) Retrieved Brewery ID 5855...
# (31/100) Retrieved Brewery ID 1790...
# (32/100) Retrieved Brewery ID 5319...
# (33/100) Retrieved Brewery ID 4340...
# (34/100) Retrieved Brewery ID 4278...
# (35/100) Retrieved Brewery ID 5107...
# (36/100) Retrieved Brewery ID 5342...
# (37/100) Retrieved Brewery ID 2192...
# (38/100) Retrieved Brewery ID 696...
# (39/100) Retrieved Brewery ID 3328...
# (40/100) Retrieved Brewery ID 1540...
# (41/100) Retrieved Brewery ID 4131...
# (42/100) Retrieved Brewery ID 5373...
# (43/100) Retrieved Brewery ID 2090...
# (44/100) Retrieved Brewery ID 3003...
# (45/100) Retrieved Brewery ID 2982...
# (46/100) Retrieved Brewery ID 373...
# (47/100) Retrieved Brewery ID 779...
# (48/100) Retrieved Brewery ID 4092...
# (49/100) Retrieved Brewery ID 2129...
# (50/100) Retrieved Brewery ID 1194...
# (51/100) Retrieved Brewery ID 3813...
# (52/100) Retrieved Brewery ID 4198...
# (53/100) Retrieved Brewery ID 4464...
# (54/100) Retrieved Brewery ID 4628...
# (55/100) Retrieved Brewery ID 979...
# (56/100) Retrieved Brewery ID 351...
# (57/100) Retrieved Brewery ID 564...
# (58/100) Retrieved Brewery ID 582...
# (59/100) Retrieved Brewery ID 2549...
# (60/100) Retrieved Brewery ID 4413...
# (61/100) Retrieved Brewery ID 2654...
# (62/100) Retrieved Brewery ID 4087...
# (63/100) Retrieved Brewery ID 5492...
# (64/100) Retrieved Brewery ID 2996...
# (65/100) Retrieved Brewery ID 2248...
# (66/100) Retrieved Brewery ID 5115...
# (67/100) Retrieved Brewery ID 1268...
# (68/100) Retrieved Brewery ID 3408...
# (69/100) Retrieved Brewery ID 3375...
# (70/100) Retrieved Brewery ID 4468...
# (71/100) Retrieved Brewery ID 1444...
# (72/100) Retrieved Brewery ID 1047...
# (73/100) Retrieved Brewery ID 4382...
# (74/100) Retrieved Brewery ID 2642...
# (75/100) Retrieved Brewery ID 4552...
# (76/100) Retrieved Brewery ID 1568...
# (77/100) Retrieved Brewery ID 1188...
# (78/100) Retrieved Brewery ID 314...
# (79/100) Retrieved Brewery ID 2781...
# (80/100) Retrieved Brewery ID 5688...
# (81/100) Retrieved Brewery ID 609...
# (82/100) Retrieved Brewery ID 3356...
# (83/100) Retrieved Brewery ID 3410...
# (84/100) Retrieved Brewery ID 1245...
# (85/100) Retrieved Brewery ID 4223...
# (86/100) Retrieved Brewery ID 3727...
# (87/100) Retrieved Brewery ID 481...
# (88/100) Retrieved Brewery ID 3998...
# (89/100) Retrieved Brewery ID 3147...
# (90/100) Retrieved Brewery ID 2515...
# (91/100) Retrieved Brewery ID 1376...
# (92/100) Retrieved Brewery ID 4878...
# (93/100) Retrieved Brewery ID 1896...
# (94/100) Retrieved Brewery ID 2433...
# (95/100) Retrieved Brewery ID 982...
# (96/100) Retrieved Brewery ID 3984...
# (97/100) Retrieved Brewery ID 64...
# (98/100) Retrieved Brewery ID 3534...
# (99/100) Retrieved Brewery ID 2136...
# (100/100) Retrieved Brewery ID 1390...
#
# Retrieved 100 breweries... Time elapsed: 0.28 minutes.

# %%
# Creating DataFrame
brewery_df = pd.DataFrame(raw_brewery_data)
brewery_df.to_csv("raw_brewery_data.csv")
brewery_df
# Out:
#    brewery_type              city        country    id          latitude  \
# 0       brewpub         Johnstown  United States  1613          40.33713
# 1      planning       Kansas City  United States  4003              None
# 2         micro         San Diego  United States   751         32.711658
# 3         micro            Oxford  United States  1707              None
# 4         micro     San Francisco  United States   342       37.74000915
# 5       brewpub            Nenana  United States    86              None
# 6         micro           Pomeroy  United States  5499         39.027513
# 7         micro            Duluth  United States  3874              None
# 9                None           Eastern Front Brewing Co  6319051535
# 10               None                  Turgua Brewing Co  8282220984
# 11  -85.8943742260864        Paw Paw Brewing Company LLC  2695015241
# 12               None           Huntington Beach Beer Co  7149605343
# 13  -92.0693151818361               Broken Wheel Brewery  3182536543
# 14               None                 Hideout Brewing Co  6163619658
# 15               None        Revelation Craft Brewing Co  3022125674
# 16  -122.191420172955       Cleophus Quealy Beer Company
# 17  -81.4723705789474              McArthur's Brew House  3308054600
# 18               None       Brewery In Planning - Bolton  9788955931
# 19   -122.55705476448      Moylan's Brewery & Restaurant  4158984677
# 20         -89.615349        Generations Brewing Company  8156165941
# 21        -117.255265            Pacific Beach Ale House  8585812337
# 22               None              RiverBend Brewing Pub  5415507550
# 23  -71.4689918739142                        Aigean Ales  6035188550
# 24  -94.1652437133366                Hog Haus Brewing Co  4792833516
# 25  -93.1907182857143               Lake Monster Brewing
# 26  -87.6988904994196           Middle Brow Beer Company  7088465511
# 27               None            Public House Brewing Co  5732613333
# 28       -122.6391907   Dempsey's Restaurant And Brewery  7077659694
# 29    -122.6708111765               McMenamins Breweries  5032230109
# ..                ...                                ...         ...
# 70  -105.477435203567        Mad Jack's Mountain Brewery  3038162337
# 71  -116.867513220741                       Star B Ranch
# 72               None   Brewery in Planning - Asbury, NJ  9088924603
# 73               None           Guggman Haus Brewing Co.  8122302554
# 74  -105.990999285302     Second Street Brewery - Rufina  5059823030
# 75       -105.2378323              Stein Brewing Company  3033960384
# 76  -118.316350719908       Yorkshire Square Brewing Co.  4243765115
# 77       -122.4011065                  Anchor Brewing Co  4158638350
# 78        -91.7075553             Kalona Brewing Company  3196563335
# 79               None             Stonecloud Brewing Co.  4056023966
# 80               None                  Flat Fish Brewing  8054849600
# 81        -71.0890345         Somerville Brewing Company  8004281150
# 82  -85.8496644285714                       Barn Brewers  2692990482
# 83  -105.106280819542                  Bootstrap Brewing  3036524186
# 84       -100.7916041               Pals Brewing Company  6088079332
# 85        -85.6204308                         The Parlor  2319414422
# 86               None              Cismontane Brewing Co  9498882739
# 87        -90.2439837           Cathedral Square Brewery  3148033605
# 88               None        Greenspring Brewing Company  4102063918
# 89   -88.303969703463         Scorched Earth Brewing Co.  2242098472
# 90   -104.98981685351            Good River Beer Company  6023697442
# 91  -77.5979331666667                     Roc Brewing Co  5857949798
# 92               None                     Destin Brewery
# 93               None            Knox County Brewing Co.  5126528793
# 94               None                 Sanctum Brewing Co  9093450253
# 95               None                  Boat Town Brewing  4175332306
# 96       -149.1540907           Girdwood Brewing Company      907783
# 97         -84.406597                Grand River Brewery  5179622427
# 98               None        Eagle Creek Brewing Company  9124892337
# 99               None  Grist Brewing Company - Lone Tree  3037289394
#
#    postal_code           state                          street  \
# 0        80534        Colorado                 21 N Parish Ave
# 1   64108-1803        Missouri
# 2   92101-6425      California                   842 Market St
# 3   06478-3162     Connecticut                 7 Fox Hollow Rd
# 4   94110-5714      California               1525 Cortland Ave
# 5   99760-9999          Alaska                  623 North A St
# 6   45769-1004            Ohio                110 Mulberry Ave
# 90  2018-08-24T00:23:12.094Z                         http://www.grbeerco.com
# 91  2018-08-24T15:40:04.696Z                     http://www.rocbrewingco.com
# 92  2018-08-11T21:36:53.619Z                    http://www.destinbrewery.com
# 93  2018-08-11T21:37:13.011Z                     http://www.knoxcobrewco.com
# 94  2018-08-11T21:36:19.381Z                   http://www.sanctumbrewing.com
# 95  2018-08-11T21:38:06.745Z                  http://www.boattownbrewing.com
# 96  2018-08-23T23:20:47.669Z                  http://www.girdwoodbrewing.com
# 97  2018-08-24T00:43:02.095Z            http://www.grandrivermarketplace.com
# 98  2018-08-11T21:37:01.580Z              http://www.eaglecreekbrewingco.com
# 99  2018-08-11T21:36:36.830Z
#
# [100 rows x 13 columns]

# %%
# Drop rows with "None" Lats/Lngs
brewery_df = brewery_df[brewery_df.latitude.str.contains("None") == False]
print(f"Dropped {len(unique_id) - len(brewery_df)} breweries from DataFrame which did not have coordinates.\nTotal Brewery count: {len(brewery_df)}")
# Out:
# Dropped 45 breweries from DataFrame which did not have coordinates.
# Total Brewery count: 55

# %%
brewery_loc = brewery_df[['latitude','longitude']].astype(float)
brewery_loc.head()
# Out:
#      latitude   longitude
# 0   40.337130 -104.906192
# 2   32.711658 -117.127434
# 4   37.740009 -122.409040
# 6   39.027513  -82.034268
# 11  42.213139  -85.894374

# %%
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(brewery_loc, dissipating=False, max_intensity=10, point_radius=1)

# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#Grabbing list of breweries from brewery_df
brewery_names = brewery_df['name'].tolist()
brewery_cities = brewery_df['city'].tolist()

# %%
#Grabbing weather info for cities
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{url}appid={w_key}&units={units}&q="
temps=[]
for city in brewery_cities:
    city_dic = {'name':'','temp':''}
    response = requests.get(query_url + city).json()
    city_dic['name'] = response['name']
    city_dic['temp'] = response['main']['temp_max']
    temps.append(city_dic)
# Out:
# 55

# %%
#Turn weather info into dataframe
temp_df = pd.DataFrame(temps)
temp_df = temp_df.rename(columns = {'name':'city'})
temp_df.head()
# Out:
#             city   temp
# 0      Johnstown  68.00
# 1      San Diego  75.20
# 2  San Francisco  76.64
# 3        Pomeroy  60.08
# 4        Paw Paw  62.60

# %%
#Grabbing Brewery info
#base url for google places
base_url2 = "https://maps.googleapis.com/maps/api/place/findplacefromtext/json"
ratings=[]
bad_names = []
for name in brewery_names:
    rat_dic = {'name': name,'rating':''}
    params = {'input': name, 'inputtype': 'textquery',
          'fields':'rating', 'key': api_key }
    response = requests.get(base_url2, params=params).json()
    try:
        rat_dic['rating'] = response['candidates'][0]['rating']
        ratings.append(rat_dic)
    except:
        #creating a list of names that don't return anything 
        bad_names.append(name)

# %%
ratings_df = pd.DataFrame(ratings)
ratings_df.head()
# Out:
#                           name  rating
# 0           Knotty Brewing Co.     4.8
# 1   Barebottle Brewing Company     4.6
# 2           Maple Lawn Brewery     4.8
# 3  Paw Paw Brewing Company LLC     4.4
# 4         Broken Wheel Brewery     4.0

# %%
# Out:
# 'https://maps.googleapis.com/maps/api/place/findplacefromtext/json?input=Good River Beer Companyinputtype=textquery&fields=photos,formatted_address,name,rating,opening_hours,geometry&key=AIzaSyDKvMaO6kvXc_WC4nuzEAocyMHPo2wfYng'
